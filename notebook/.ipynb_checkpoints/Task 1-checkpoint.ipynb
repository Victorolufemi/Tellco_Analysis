# %%
import sys

sys.path.append("../scripts")

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/Week1_challenge_data_source.csv")

# %%
from Eda import Eda as eda
eda = eda(data)

# %%
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311450e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311450e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311450e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311450e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311450e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI Last Location Name  \
# 0  1823652.0  2.082010e+14   3.366496e+10  3.552120e+13        9.16457E+15
# 1  1365104.0  2.082020e+14   3.368185e+10  3.579400e+13            L77566A
# 2  1361762.0  2.082000e+14   3.376063e+10  3.528150e+13            D42335A
# 3  1321509.0  2.082010e+14   3.375034e+10  3.535660e+13            T21824A
# 4  1089009.0  2.082010e+14   3.369980e+10  3.540700e+13            D88865A
#
#    ...  Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# 0  ...          15854611.0           2501332.0           8198936.0
# 1  ...          20247395.0          19111729.0          18338413.0
# 2  ...          19725661.0          14699576.0          17587794.0
# 3  ...          21388122.0          15146643.0          13994646.0
# 4  ...          15259380.0          18962873.0          17124581.0
#
#    Netflix UL (Bytes)  Gaming DL (Bytes)  Gaming UL (Bytes)  Other DL (Bytes)  \
# 0           9656251.0        278082303.0         14344150.0       171744450.0
# 1          17227132.0        608750074.0          1170709.0       526904238.0
# 2           6163408.0        229584621.0           395630.0       410692588.0
# 3           1097942.0        799538153.0         10849722.0       749039933.0
# 4            415218.0        527707248.0          3529801.0       550709500.0
#
#    Other UL (Bytes)  Total UL (Bytes)  Total DL (Bytes)
# 0         8814393.0        36749741.0       308879636.0
# 1        15055145.0        53800391.0       653384965.0
# 2         4215763.0        27883638.0       279807335.0
# 3        12797283.0        43324218.0       846028530.0
# 4        13910322.0        38542814.0       569138589.0
#
# [5 rows x 55 columns]

# %%
data = eda.convertbyte_scale(data, '(Bytes)', '(MB)', 1000000)

# %%
data['Total_Data_Volume(MB)'] = data['Total DL (MB)'] + data['Total UL (MB)']

# %%
num_col, cat_col = eda.col_assign(data)

# %%
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311450e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311450e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311450e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311450e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311450e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI Last Location Name  \
# 0  1823652.0  2.082010e+14   3.366496e+10  3.552120e+13        9.16457E+15
# 1  1365104.0  2.082020e+14   3.368185e+10  3.579400e+13            L77566A
# 2  1361762.0  2.082000e+14   3.376063e+10  3.528150e+13            D42335A
# 3  1321509.0  2.082010e+14   3.375034e+10  3.535660e+13            T21824A
# 4  1089009.0  2.082010e+14   3.369980e+10  3.540700e+13            D88865A
#
#    ...  Youtube UL (MB)  Netflix DL (MB)  Netflix UL (MB)  Gaming DL (MB)  \
# 0  ...            2.501            8.199            9.656         278.082
# 1  ...           19.112           18.338           17.227         608.750
# 2  ...           14.700           17.588            6.163         229.585
# 3  ...           15.147           13.995            1.098         799.538
# 4  ...           18.963           17.125            0.415         527.707
#
#    Gaming UL (MB)  Other DL (MB)  Other UL (MB)  Total UL (MB)  Total DL (MB)  \
# 0          14.344        171.744          8.814         36.750        308.880
# 1           1.171        526.904         15.055         53.800        653.385
# 2           0.396        410.693          4.216         27.884        279.807
# 3          10.850        749.040         12.797         43.324        846.029
# 4           3.530        550.710         13.910         38.543        569.139
#
#    Total_Data_Volume(MB)
# 0                345.630
# 1                707.185
# 2                307.691
# 3                889.353
# 4                607.682
#
# [5 rows x 56 columns]

# %%
cat_col
# Out:
# ['Start', 'End', 'Last Location Name', 'Handset Manufacturer', 'Handset Type']

# %%
top_10_handset = eda.top_produce(data, 'Handset Type', 10)

# %%
top_10_handset
# Out:
#                               Handset Type
# Huawei B528S-23A                     19752
# Apple iPhone 6S (A1688)               9419
# Apple iPhone 6 (A1586)                9023
# undefined                             8987
# Apple iPhone 7 (A1778)                6326
# Apple iPhone Se (A1723)               5187
# Apple iPhone 8 (A1905)                4993
# Apple iPhone Xr (A2105)               4568
# Samsung Galaxy S8 (Sm-G950F)          4520
# Apple iPhone X (A1901)                3813

# %%
top_3_manu = eda.top_produce(data, 'Handset Manufacturer', 3)

# %%
top_3_manu
# Out:
#          Handset Manufacturer
# Apple                   59565
# Samsung                 40839
# Huawei                  34423

# %%
aggregation = eda.aggregation(data, 5)

# %%
aggregation
# Out:
#                      Apple  No_apple_product                       Samsung  \
# 0  Apple iPhone 6S (A1688)              9419  Samsung Galaxy S8 (Sm-G950F)
# 1   Apple iPhone 6 (A1586)              9023    Samsung Galaxy A5 Sm-A520F
# 2   Apple iPhone 7 (A1778)              6326   Samsung Galaxy J5 (Sm-J530)
# 3  Apple iPhone Se (A1723)              5187   Samsung Galaxy J3 (Sm-J330)
# 4   Apple iPhone 8 (A1905)              4993  Samsung Galaxy S7 (Sm-G930X)
#
#    No_samsung_product                          Huawei  No_huawei_product
# 0                4520                Huawei B528S-23A              19752
# 1                3724                    Huawei E5180               2079
# 2                3696  Huawei P20 Lite Huawei Nova 3E               2021
# 3                3484                      Huawei P20               1480
# 4                3199                  Huawei Y6 2018                997

# %% [markdown]
# ## TASK 1

# %% [markdown]
# ### 1.1

# %% [markdown]
# ###### Aggregate per user number of xDR sessions

# %%
agg = data.groupby(['MSISDN/Number']).agg(MSISDN_PER_DUR = ('Dur. (ms)', 'count'))
agg
# Out:
#                MSISDN_PER_DUR
# MSISDN/Number
# 3.360100e+10                1
# 3.360100e+10                1
# 3.360100e+10                1
# 3.360101e+10                1
# 3.360101e+10                2
# ...                       ...
# 3.379000e+10                1
# 3.379000e+10                1
# 3.197020e+12                1
# 3.370000e+14                1
# 8.823970e+14                1
#
# [106856 rows x 1 columns]

# %% [markdown]
# ###### Aggregate per user sessions duration

# %%
agg1 = data.groupby(['MSISDN/Number']).agg(MSISDN_PER_SES = ('Dur. (ms)', sum))

# %%
agg1
# Out:
#                MSISDN_PER_SES
# MSISDN/Number
# 3.360100e+10         116720.0
# 3.360100e+10         181230.0
# 3.360100e+10         134969.0
# 3.360101e+10          49878.0
# 3.360101e+10          37104.0
# ...                       ...
# 3.379000e+10           8810.0
# 3.379000e+10         140988.0
# 3.197020e+12         877385.0
# 3.370000e+14         253030.0
# 8.823970e+14         869844.0
#
# [106856 rows x 1 columns]

# %% [markdown]
# ######  Aggregate per user total upload

# %%
UL_agg = data.groupby(['MSISDN/Number'],as_index=False).agg({'Total UL (MB)': ['min', 'max', sum]})

# %%
UL_agg
# Out:
#        MSISDN/Number Total UL (MB)
#                                min     max     sum
# 0       3.360100e+10        36.053  36.053  36.053
# 1       3.360100e+10        36.104  36.104  36.104
# 2       3.360100e+10        39.307  39.307  39.307
# 3       3.360101e+10        20.328  20.328  20.328
# 4       3.360101e+10        38.481  55.799  94.280
# ...              ...           ...     ...     ...
# 106851  3.379000e+10        26.716  26.716  26.716
# 106852  3.379000e+10        35.732  35.732  35.732
# 106853  3.197020e+12        37.296  37.296  37.296
# 106854  3.370000e+14        56.653  56.653  56.653
# 106855  8.823970e+14        60.456  60.456  60.456
#
# [106856 rows x 4 columns]

# %% [markdown]
# ######  Aggregate per user total download

# %%
DL_agg = data.groupby(['MSISDN/Number'],as_index=False).agg({'Total DL (MB)': ['min', 'max', sum]})

# %%
DL_agg
# Out:
#        MSISDN/Number Total DL (MB)
#                                min      max       sum
# 0       3.360100e+10       842.637  842.637   842.637
# 1       3.360100e+10       120.755  120.755   120.755
# 2       3.360100e+10       556.660  556.660   556.660
# 3       3.360101e+10       401.993  401.993   401.993
# 4       3.360101e+10       547.097  816.033  1363.130
# ...              ...           ...      ...       ...
# 106851  3.379000e+10       687.925  687.925   687.925
# 106852  3.379000e+10       444.575  444.575   444.575
# 106853  3.197020e+12       194.828  194.828   194.828
# 106854  3.370000e+14       539.635  539.635   539.635
# 106855  8.823970e+14        78.698   78.698    78.698
#
# [106856 rows x 4 columns]

# %% [markdown]
# ######  Aggregate per user total download

# %%
DV_agg = data.groupby(['MSISDN/Number'],as_index=False).agg({'Total_Data_Volume(MB)': ['min', 'max', sum]})
DV_agg
# Out:
#        MSISDN/Number Total_Data_Volume(MB)
#                                        min      max       sum
# 0       3.360100e+10               878.690  878.690   878.690
# 1       3.360100e+10               156.859  156.859   156.859
# 2       3.360100e+10               595.967  595.967   595.967
# 3       3.360101e+10               422.321  422.321   422.321
# 4       3.360101e+10               585.578  871.832  1457.410
# ...              ...                   ...      ...       ...
# 106851  3.379000e+10               714.641  714.641   714.641
# 106852  3.379000e+10               480.307  480.307   480.307
# 106853  3.197020e+12               232.124  232.124   232.124
# 106854  3.370000e+14               596.288  596.288   596.288
# 106855  8.823970e+14               139.154  139.154   139.154
#
# [106856 rows x 4 columns]

# %% [markdown]
# ### 1.2

# %% [markdown]
# ##### Performing Data Cleaning

# %%
data = eda.fix_cat_cols(data, cat_col)

# %%
data = eda.fix_num_cols(data, num_col)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 56 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 150001 non-null  float64
#  1   Start                                     150001 non-null  object
#  2   Start ms                                  150001 non-null  float64
#  3   End                                       150001 non-null  object
#  4   End ms                                    150001 non-null  float64
#  5   Dur. (ms)                                 150001 non-null  float64
#  6   IMSI                                      150001 non-null  float64
#  7   MSISDN/Number                             150001 non-null  float64
#  8   IMEI                                      150001 non-null  float64
#  9   Last Location Name                        150001 non-null  object
#  10  Avg RTT DL (ms)                           150001 non-null  float64
#  11  Avg RTT UL (ms)                           150001 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150001 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150001 non-null  float64
#  14  DL TP < 50 Kbps (%)                       150001 non-null  float64
#  15  50 Kbps < DL TP < 250 Kbps (%)            150001 non-null  float64
#  16  250 Kbps < DL TP < 1 Mbps (%)             150001 non-null  float64
#  17  DL TP > 1 Mbps (%)                        150001 non-null  float64
#  18  UL TP < 10 Kbps (%)                       150001 non-null  float64
#  19  10 Kbps < UL TP < 50 Kbps (%)             150001 non-null  float64
#  20  50 Kbps < UL TP < 300 Kbps (%)            150001 non-null  float64
#  21  UL TP > 300 Kbps (%)                      150001 non-null  float64
#  22  Activity Duration DL (ms)                 150001 non-null  float64
#  23  Activity Duration UL (ms)                 150001 non-null  float64
#  24  Dur. (ms).1                               150001 non-null  float64
#  25  Handset Manufacturer                      150001 non-null  object
#  26  Handset Type                              150001 non-null  object
#  27  Nb of sec with 125000B < Vol DL           150001 non-null  float64
#  28  Nb of sec with 1250B < Vol UL < 6250B     150001 non-null  float64
#  29  Nb of sec with 31250B < Vol DL < 125000B  150001 non-null  float64
#  30  Nb of sec with 37500B < Vol UL            150001 non-null  float64
#  31  Nb of sec with 6250B < Vol DL < 31250B    150001 non-null  float64
#  32  Nb of sec with 6250B < Vol UL < 37500B    150001 non-null  float64
#  33  Nb of sec with Vol DL < 6250B             150001 non-null  float64
#  34  Nb of sec with Vol UL < 1250B             150001 non-null  float64
#  35  TCP DL Retrans. Vol (MB)                  150001 non-null  float64
#  36  TCP UL Retrans. Vol (MB)                  150001 non-null  float64
#  37  HTTP DL (MB)                              150001 non-null  float64
#  38  HTTP UL (MB)                              150001 non-null  float64
#  39  Social Media DL (MB)                      150001 non-null  float64
#  40  Social Media UL (MB)                      150001 non-null  float64
#  41  Google DL (MB)                            150001 non-null  float64
#  42  Google UL (MB)                            150001 non-null  float64
#  43  Email DL (MB)                             150001 non-null  float64
#  44  Email UL (MB)                             150001 non-null  float64
#  45  Youtube DL (MB)                           150001 non-null  float64
#  46  Youtube UL (MB)                           150001 non-null  float64
#  47  Netflix DL (MB)                           150001 non-null  float64
#  48  Netflix UL (MB)                           150001 non-null  float64
#  49  Gaming DL (MB)                            150001 non-null  float64
#  50  Gaming UL (MB)                            150001 non-null  float64
#  51  Other DL (MB)                             150001 non-null  float64
#  52  Other UL (MB)                             150001 non-null  float64
#  53  Total UL (MB)                             150001 non-null  float64
#  54  Total DL (MB)                             150001 non-null  float64
#  55  Total_Data_Volume(MB)                     150001 non-null  float64
# dtypes: float64(51), object(5)
# memory usage: 64.1+ MB

# %%
outliers = ['Avg RTT DL (ms)', 'Avg RTT UL (ms)','TCP DL Retrans. Vol (MB)','TCP UL Retrans. Vol (MB)','Avg Bearer TP DL (kbps)','Avg Bearer TP UL (kbps)']

# %%
data = eda.fix_outlier(data, outliers)

# %% [markdown]
# ###### 	Describe all relevant variables and associated data types

# %%
df = pd.DataFrame()
df['Dur. (s)'] = data['Dur. (ms)']/1000
df['Total UL (MB)'] = data['Total UL (MB)']
df['Total DL (MB)'] = data['Total DL (MB)']
df['Google_total (MB)'] = data['Google DL (MB)'] + data['Google UL (MB)']
df['Social_total (MB)'] = data['Social Media DL (MB)'] + data['Social Media UL (MB)']
df['Email_total (MB)'] = data['Email DL (MB)'] + data['Email UL (MB)']
df['Youtube_total (MB)'] = data['Youtube DL (MB)'] + data['Youtube UL (MB)']
df['Netflix_total (MB)'] = data['Netflix DL (MB)'] + data['Netflix UL (MB)']
df['Gaming_total (MB)'] = data['Gaming DL (MB)'] + data['Gaming UL (MB)']
df['Other_total (MB)'] = data['Other DL (MB)'] + data['Other UL (MB)']
df['Total_data (MB)'] = data['Total_Data_Volume(MB)']
df['MSISDN/Number'] = data['MSISDN/Number']
df.head()
# Out:
#    Dur. (s)  Total UL (MB)  Total DL (MB)  Google_total (MB)  \
# 0  1823.652         36.750        308.880              2.905
# 1  1365.104         53.800        653.385              4.414
# 2  1361.762         27.884        279.807             10.229
# 3  1321.509         43.324        846.029             11.812
# 4  1089.009         38.543        569.139              7.749
#
#    Social_total (MB)  Email_total (MB)  Youtube_total (MB)  \
# 0              1.570             3.702              18.356
# 1              1.933             0.937              39.359
# 2              1.726             3.363              34.426
# 3              0.657             2.071              36.535
# 4              0.913             2.110              34.222
#
#    Netflix_total (MB)  Gaming_total (MB)  Other_total (MB)  Total_data (MB)  \
# 0              17.855            292.426           180.558          345.630
# 1              35.565            609.921           541.959          707.185
# 2              23.751            229.981           414.909          307.691
# 3              15.093            810.388           761.837          889.353
# 4              17.540            531.237           564.620          607.682
#
#    MSISDN/Number
# 0   3.366496e+10
# 1   3.368185e+10
# 2   3.376063e+10
# 3   3.375034e+10
# 4   3.369980e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Dur. (s)            150001 non-null  float64
#  1   Total UL (MB)       150001 non-null  float64
#  2   Total DL (MB)       150001 non-null  float64
#  3   Google_total (MB)   150001 non-null  float64
#  4   Social_total (MB)   150001 non-null  float64
#  5   Email_total (MB)    150001 non-null  float64
#  6   Youtube_total (MB)  150001 non-null  float64
#  7   Netflix_total (MB)  150001 non-null  float64
#  8   Gaming_total (MB)   150001 non-null  float64
#  9   Other_total (MB)    150001 non-null  float64
#  10  Total_data (MB)     150001 non-null  float64
#  11  MSISDN/Number       150001 non-null  float64
# dtypes: float64(12)
# memory usage: 13.7 MB

# %%
relevant_variables = ['Dur. (s)', 'Total UL (MB)', 'Total DL (MB)', 'Google_total (MB)',
       'Social_total (MB)', 'Email_total (MB)', 'Youtube_total (MB)',
       'Netflix_total (MB)', 'Gaming_total (MB)']

# %%
eda.describes(df, relevant_variables)
# Out:
#             Dur. (s)
# count  150001.000000
# mean      104.608560
# std        81.037351
# min         7.142000
# 25%        57.442000
# 50%        86.399000
# 75%       132.430000
# max      1859.336000
# Column name is Dur. (s)
#        Total UL (MB)
# count  150001.000000
# mean       41.121206
# std        11.276348
# min         2.867000
# 25%        33.222000
# 50%        41.143000
# 75%        49.034000
# max        78.331000
# Column name is Total UL (MB)
#        Total DL (MB)
# count  150001.000000
# mean      454.643429
# std       244.142061
# min         7.114000
# 25%       243.107000
# 50%       455.841000
# 75%       665.705000
# max       902.970000
# Column name is Total DL (MB)
#        Google_total (MB)
# count      150001.000000
# mean            7.807295
# std             3.516420
# min             0.040000
# 25%             4.944000
# 50%             7.813000
# 75%            10.683000
# max            15.529000
# Column name is Google_total (MB)
#        Social_total (MB)
# count      150001.000000
# mean            1.828250
# std             1.035648
# min             0.001000
# 25%             0.932000
# 50%             1.826000
# 75%             2.727000
# max             3.651000
# Column name is Social_total (MB)
#        Email_total (MB)
# count     150001.000000
# mean           2.259102
# std            1.071108
# min            0.009000
# 25%            1.359000
# 50%            2.264000
# 75%            3.160000
# max            4.518000
# Column name is Email_total (MB)
#        Youtube_total (MB)
# count       150001.000000
# mean            22.643482
# std              9.246802
# min              0.079000
# 25%             15.999000
# 50%             22.662000
# 75%             29.293000
# max             45.190000
# Column name is Youtube_total (MB)
#        Netflix_total (MB)
# count       150001.000000
# mean            22.628607
# std              9.260822
# min              0.098000
# 25%             15.979000
# 50%             22.635000
# 75%             29.290000
# max             45.198000
# Column name is Netflix_total (MB)
#        Gaming_total (MB)
# count      150001.000000
# mean          430.333100
# std           244.019924
# min             0.306000
# 25%           218.727000
# 50%           431.615000
# 75%           641.416000
# max           859.202000
# Column name is Gaming_total (MB)

# %% [markdown]
# ###### Conduct a Non-Graphical Univariate Analysis

# %%
eda.non_grahical_EDA(df, relevant_variables)
# Out:
# Column name is Dur. (s)
# skewness for this column is 3.952621786921105
# kurtosis for this column is 37.0224540863713
# The IQR is 74.988
# The number of Unique value of column Dur. (s) is : 89526
# ____________________________________________________________________
# Column name is Total UL (MB)
# skewness for this column is -0.002456396188635827
# kurtosis for this column is -0.32743595188862207
# The IQR is 15.811999999999998
# The number of Unique value of column Total UL (MB) is : 45811
# ____________________________________________________________________
# Column name is Total DL (MB)
# skewness for this column is -0.003153365529645234
# kurtosis for this column is -1.1983632219345253
# The IQR is 422.59800000000007
# The number of Unique value of column Total DL (MB) is : 137678
# ____________________________________________________________________
# Column name is Google_total (MB)
# skewness for this column is -0.010601601656101434
# kurtosis for this column is -0.9630336232073042
# The IQR is 5.739
# The number of Unique value of column Google_total (MB) is : 25088
# ____________________________________________________________________
# Column name is Social_total (MB)
# skewness for this column is -0.002118188087751061
# kurtosis for this column is -1.202174480170279
# The IQR is 1.7950000000000004
# The number of Unique value of column Social_total (MB) is : 6531
# ____________________________________________________________________
# Column name is Email_total (MB)
# skewness for this column is -0.0060291718932214
# kurtosis for this column is -1.0616958381765758
# The IQR is 1.8010000000000002
# The number of Unique value of column Email_total (MB) is : 8260
# ____________________________________________________________________
# Column name is Youtube_total (MB)
# skewness for this column is -0.0054651413260755465
# kurtosis for this column is -0.6046245183051515
# The IQR is 13.294
# The number of Unique value of column Youtube_total (MB) is : 53314
# ____________________________________________________________________
# Column name is Netflix_total (MB)
# skewness for this column is -0.00041017117595583966
# kurtosis for this column is -0.6084725068651227
# The IQR is 13.311
# The number of Unique value of column Netflix_total (MB) is : 53276
# ____________________________________________________________________
# Column name is Gaming_total (MB)
# skewness for this column is -0.0032248952108392065
# kurtosis for this column is -1.202256256783853
# The IQR is 422.6890000000001
# The number of Unique value of column Gaming_total (MB) is : 141458
# ____________________________________________________________________

# %% [markdown]
# ###### 	Conduct a Graphical Univariate Analysis

# %%
eda.univariate_plot(df, relevant_variables)

# %% [markdown]
# ###### 	Conduct a Graphical Bivariate Analysis

# %%
relevant_apps = ['Google_total (MB)',
       'Social_total (MB)', 'Email_total (MB)', 'Youtube_total (MB)',
       'Netflix_total (MB)', 'Gaming_total (MB)']

# %%
eda.bivariate_plot(df, relevant_apps, 'Total_data (MB)')

# %% [markdown]
# ###### 	Variable transformations

# %%
Top_5_decile = eda.variable_transformation(df, 'Dur. (s)', 'Top_5_decile')

# %%
Top_5_decile
# Out:
#        MSISDN/Number  total_data_volume  top_5_decile_Dur. (s)
# 0       4.188282e+10            157.443                      3
# 1       3.369907e+10            659.161                      3
# 2       3.363783e+10            549.853                      3
# 3       3.363241e+10            460.886                      3
# 4       3.365856e+10             76.046                      3
# ...              ...                ...                    ...
# 14995   3.366047e+10            320.541                      7
# 14996   3.369592e+10            427.883                      7
# 14997   3.366495e+10            185.829                      7
# 14998   3.362600e+10            332.683                      7
# 14999   3.366691e+10            426.120                      7
#
# [92705 rows x 3 columns]

# %% [markdown]
# ###### 	Correlation Analysis

# %%
relevant_app = ['Google_total (MB)',
       'Social_total (MB)', 'Email_total (MB)', 'Youtube_total (MB)',
       'Netflix_total (MB)', 'Gaming_total (MB)', 'Other_total (MB)']

# %%
eda.corr(df, relevant_app)
# Out:
#                     Google_total (MB)  Social_total (MB)  Email_total (MB)  \
# Google_total (MB)            1.000000          -0.001709         -0.000412
# Social_total (MB)           -0.001709           1.000000          0.004033
# Email_total (MB)            -0.000412           0.004033          1.000000
# Youtube_total (MB)           0.002276           0.000547         -0.002917
# Netflix_total (MB)          -0.001903           0.001015          0.001029
# Gaming_total (MB)           -0.000995           0.001083         -0.000644
# Other_total (MB)            -0.001727           0.006063         -0.001299
#
#                     Youtube_total (MB)  Netflix_total (MB)  Gaming_total (MB)  \
# Google_total (MB)             0.002276           -0.001903          -0.000995
# Social_total (MB)             0.000547            0.001015           0.001083
# Email_total (MB)             -0.002917            0.001029          -0.000644
# Youtube_total (MB)            1.000000            0.002882          -0.002999
# Netflix_total (MB)            0.002882            1.000000          -0.003109
# Gaming_total (MB)            -0.002999           -0.003109           1.000000
# Other_total (MB)              0.002969           -0.009033          -0.002661
#
#                     Other_total (MB)
# Google_total (MB)          -0.001727
# Social_total (MB)           0.006063
# Email_total (MB)           -0.001299
# Youtube_total (MB)          0.002969
# Netflix_total (MB)         -0.009033
# Gaming_total (MB)          -0.002661
# Other_total (MB)            1.000000

# %% [markdown]
# ###### PCA

# %%
PCA_df = eda.PCA(df, 'column1', 'column2')

# %%
PCA_df
# Out:
#              column1     column2
# 0      -8.217856e+09  249.630701
# 1      -8.200964e+09 -340.468389
# 2      -8.122191e+09  324.961012
# 3      -8.132475e+09 -672.082273
# 4      -8.183023e+09 -188.833284
# ...              ...         ...
# 149996 -8.232130e+09 -209.397411
# 149997 -8.219369e+09 -359.233188
# 149998 -8.260928e+09 -235.449952
# 149999 -8.263197e+09  146.534750
# 150000 -4.348760e-04    0.000053
#
# [150001 rows x 2 columns]
